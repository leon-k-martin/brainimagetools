# %% [markdown]
# # Surface plotting

# %%
from brainvistools import surf
import matplotlib.pyplot as plt
from brainvistools import surface

from brainvistools import surf

from brainvistools.surf.imgmap import mlab_imgmap, render_mesh, get_hemisphere_data
import hcp_utils as hcp
import numpy as np
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
surf.plot.surf_vtk2mpl()
# Out:
# 327684

# %%
from templateflow.api import get

hemi = "L"
get("fsLR", density="32k", hemi=hemi, suffix="inflated", desc=None)
# Out:
# PosixPath('/Users/leonmartin_bih/.cache/templateflow/tpl-fsLR/tpl-fsLR_den-32k_hemi-L_inflated.surf.gii')

# %%
imgmap = mlab_imgmap(
    hcp.unparcellate(np.arange(379), hcp.mmp), surface="pial", alpha_sulc=1, hemi="rh"
)
fig, ax = plt.subplots(figsize=(20, 20))
ax.axis("off")
ax.imshow(imgmap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 imgmap = mlab_imgmap(
#       2     hcp.unparcellate(np.arange(379), hcp.mmp), surface="pial", alpha_sulc=1, hemi="rh"
#       3 )
#       4 fig, ax = plt.subplots(figsize=(20, 20))
#       5 ax.axis("off")
#
# File ~/tools/brainvistools/brainvistools/surf/imgmap.py:189, in mlab_imgmap(dscalars, hemi, surface, cmap, view, figsize, alpha, alpha_sulc, bgcolor)
#     185 surf, dscalars_sulc, dscalars_ctx, azimuth = get_hemisphere_data(
#     186     hemi, dscalars, view, surface
#     187 )
#     188 rgba_vals = compute_rgba_vals(dscalars_ctx, dscalars_sulc, cmap, alpha, alpha_sulc)
# --> 189 imgmap = render_mesh(rgba_vals, surf, figsize, bgcolor, azimuth, view)
#     190 return imgmap
#
# ...

# %%
from brainvistools.surf import template

template.get_surface_data(template="fsLR", surface="inflated")
# Out:
# (array([[ 35.004333, -32.86439 ,  16.894304],
#         [ 15.553893, -28.189137,  72.46244 ],
#         [-30.412945,  23.256935,  37.84298 ],
#         ...,
#         [ 44.42798 , -19.602333, -39.161156],
#         [ 44.663612, -19.726347, -37.906113],
#         [ 44.345566, -21.345406, -38.509808]], dtype=float32),
#  array([[   68,    12,     0],
#         [  180,    12,    68],
#         [  180,    13,    12],
#         ...,
#         [53924, 64983, 40932],
#         [64983, 40933, 40932],
#         [53924, 40932, 32501]], dtype=int32))

# %%
plotter = surf.plot.surf_pyvista()
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
surf.plot.ts_surf_pyvista(parallel=False, quality=10)
# Out:
# ViewInteractiveWidget(height=768, layout=Layout(height='auto', width='100%'), width=1024)

# %%
plt.imshow(surf.plot.surf_pyvista2mpl(hemi="R"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.imshow(surf.plot.surf_pyvista2mpl(hemi='R'))
#
# TypeError: surf_pyvista2mpl() got an unexpected keyword argument 'hemi'

# %%
render_window = surf.plot.surf_vtk()
